# %%
import tensorflow
import numpy as np
import seaborn as sns
from sklearn.datasets  import make_blobs
# Out:
# C:\Users\shivang\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\shivang\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\shivang\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
X,y = make_blobs(n_samples=1000, centers =2 , random_state=42)

# %%
sns.scatterplot(X[:,0],X[:,1],hue=y)
# Out:
# <AxesSubplot:>

# %%
 y_mod = y.reshape(-1,1)

# %%
y_mod.shape
# Out:
# (1000, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
d1 = Dense(units=1,activation="sigmoid",input_shape=(2,))

# %%
model.add(d1)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 3
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.weights
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(2, 1) dtype=float32, numpy=
#  array([[ 1.36908   ],
#         [-0.29125702]], dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# from tensorflow.keras.losses import 
# from tesnorflow.keras.optimizers import 
# there are many types of losses and optimizers avaliable for selection

# %%
model.compile(optimizer = "adam", loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(X_train,y_train,epochs=10,batch_size=1000)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 287ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 2/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 3/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 4/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 5/10
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 6/10
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 7/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 8/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 9/10
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 10/10
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 1.0000

# %%
model.evaluate(X_test,y_test)
# Out:
# 11/11 [==============================] - 0s 698us/step - loss: 0.0051 - accuracy: 1.0000
# [0.005076530855149031, 1.0]

# %%
model.evaluate(X_test,y_test,verbose=0)
# Out:
# [0.005076530855149031, 1.0]
