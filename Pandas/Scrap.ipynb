# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.goodreads.com/quotes/tag/love/{}"

# %%
url.format("love")
# Out:
# 'https://www.goodreads.com/quotes/tag/love/love'

# %%
res = requests.get(url)

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="desktop\n">\n<head>\n  <title>Love Quotes (80085 quotes)</title>\n\n<meta content="80085 quotes have been tagged as love: Marilyn Monroe: ‘I\'m selfish, impatient and a little insecure. I make mistakes, I am out of control and at times h..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/quotes/tag/love\' rel=\'canonical\'>\n\n\n\n    <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();\n </script>\n  <script type="text/javascript">\n    var ue_mid = "A1PQBFHBHS6YH1";\n    var ue_sn = "www.goodreads.com";\n    var ue_furl = "fls-na.amazon.com";\n    var ue_sid = "550-8082135-4356547";\n    var ue_id = "J0HPX1E4VWAQZBRAKHMW";\n\n    (function(e){var c=e;var a=c.ue||{};a.main_scope="mainscopecsm";a.q=[];a.t0=c.ue_t0||+new Date();a.d=g;function g(h){return +new Date()-(h?0:a.t0)}function d(h){return function(){a.q.push({n:h,a:arguments,t:a.d()})}}function b(m,l,h,j,i)
# ...

# %%
soup = BeautifulSoup(res.text)

# %%
soup.title
# Out:
# <title>Love Quotes (80085 quotes)</title>

# %%
soup.head
# Out:
# <head>
# <title>Love Quotes (80085 quotes)</title>
# <meta content="80085 quotes have been tagged as love: Marilyn Monroe: ‘I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times h..." name="description"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://www.goodreads.com/quotes/tag/love" rel="canonical"/>
# <script type="text/javascript"> var ue_t0=window.ue_t0||+new Date();
#  </script>
# <script type="text/javascript">
#     var ue_mid = "A1PQBFHBHS6YH1";
#     var ue_sn = "www.goodreads.com";
#     var ue_furl = "fls-na.amazon.com";
#     var ue_sid = "550-8082135-4356547";
#     var ue_id = "J0HPX1E4VWAQZBRAKHMW";
#
# ...

# %%
soup.p
# Out:
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>

# %%
links = soup.find_all("a") # we get a list of all links in this page

# %%
dir(links[0]) # gives us all the atttributes of the first obbject link
# Out:
# ['__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
#  'descendants',
#  'encode',
# ...

# %%
dir(links[0].get("href"))
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
quotes_divs = soup.find_all("div",attrs={"class":"quote"})

# %%
quotes_divs
# Out:
# [<div class="quote mediumText">
#  <div class="quoteDetails">
#  <a class="leftAlignedImage" href="https://images.gr-assets.com/quotes/1511992603p8/8630.jpg">
#  <img alt="I'm selfish, impatient and a little insecure. I make mistakes, I am out of control" src="https://images.gr-assets.com/quotes/1511992603p2/8630.jpg"/>
#  </a>
#  <div class="quoteText">
#        “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#    <br/>  ―
#    <span class="authorOrTitle">
#      Marilyn Monroe
#    </span>
#  </div>
#  <div class="quoteFooter">
#  <div class="greyText smallText left">
#       tags:
#         <a href="/quotes/tag/attributed-no-source">attributed-no-source</a>,
#         <a href="/quotes/tag/best">best</a>,
#         <a href="/quotes/tag/life">life</a>,
#         <a href="/quotes/tag/love">love</a>,
# ...

# %%
quote_div = quotes_divs[0]

# %%
quoteText_div = quote_div.find_next("div",attrs={"class":"quoteText"})

# %%
quoteText_div
# Out:
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>

# %%
quoteText_div.text
# Out:
# "\n      “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”\n    ―\n  \n    Marilyn Monroe\n  \n"

# %%
stripped = quoteText_div.text.strip()

# %%
stripped_li = stripped.split("\n")

# %%
quote = stripped_li[0][1:-1]
author = stripped_li[-1].strip()

# %%
quote
# Out:
# "I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best."

# %%
author
# Out:
# 'Marilyn Monroe'

# %%
left_div = quote_div.find_next("div",attrs={"class":"left"})
left_div
# Out:
# <div class="greyText smallText left">
#      tags:
#        <a href="/quotes/tag/attributed-no-source">attributed-no-source</a>,
#        <a href="/quotes/tag/best">best</a>,
#        <a href="/quotes/tag/life">life</a>,
#        <a href="/quotes/tag/love">love</a>,
#        <a href="/quotes/tag/mistakes">mistakes</a>,
#        <a href="/quotes/tag/out-of-control">out-of-control</a>,
#        <a href="/quotes/tag/truth">truth</a>,
#        <a href="/quotes/tag/worst">worst</a>
# </div>

# %%
tags = [tag.text for tag in left_div.find_all("a")]

# %%
quote_div
# Out:
# <div class="quote mediumText">
# <div class="quoteDetails">
# <a class="leftAlignedImage" href="https://images.gr-assets.com/quotes/1511992603p8/8630.jpg">
# <img alt="I'm selfish, impatient and a little insecure. I make mistakes, I am out of control" src="https://images.gr-assets.com/quotes/1511992603p2/8630.jpg"/>
# </a>
# <div class="quoteText">
#       “I'm selfish, impatient and a little insecure. I make mistakes, I am out of control and at times hard to handle. But if you can't handle me at my worst, then you sure as hell don't deserve me at my best.”
#   <br/>  ―
#   <span class="authorOrTitle">
#     Marilyn Monroe
#   </span>
# </div>
# <div class="quoteFooter">
# <div class="greyText smallText left">
#      tags:
#        <a href="/quotes/tag/attributed-no-source">attributed-no-source</a>,
#        <a href="/quotes/tag/best">best</a>,
#        <a href="/quotes/tag/life">life</a>,
#        <a href="/quotes/tag/love">love</a>,
# ...

# %%
for link in links:
    print(link)
# Out:
# <a aria-label="Goodreads Home" class="siteHeader__logo" data-reactid=".rnl4h3rpc0.1.0.1" href="/" title="Goodreads Home"></a>
# <a class="siteHeader__topLevelLink" data-reactid=".rnl4h3rpc0.1.0.2.0.0.0" href="/?ref=nav_home">Home</a>
# <a class="siteHeader__topLevelLink" data-reactid=".rnl4h3rpc0.1.0.2.0.1.0" href="/review/list?ref=nav_mybooks">My Books</a>
# <a aria-expanded="false" aria-haspopup="true" class="primaryNavMenu__trigger primaryNavMenu__trigger--siteHeaderBrowseMenu" data-reactid=".rnl4h3rpc0.1.0.2.0.2.0.0" data-ux-click="true" href="/book?ref=nav_brws" role="button"><span data-reactid=".rnl4h3rpc0.1.0.2.0.2.0.0.0">Browse ▾</span></a>
# <a class="siteHeader__subNavLink" data-reactid=".rnl4h3rpc0.1.0.2.0.2.0.1.0.0.0.0" href="/recommendations?ref=nav_brws_recs">Recommendations</a>
# <a class="siteHeader__subNavLink" data-reactid=".rnl4h3rpc0.1.0.2.0.2.0.1.0.0.1.0" href="/choiceawards?ref=nav_brws_gca">Choice Awards</a>
# ...
